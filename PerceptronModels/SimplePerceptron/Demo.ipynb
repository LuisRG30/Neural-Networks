# %% [markdown]
# # Perceptron Algorithm Demo (Binary Classification)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn import datasets

# %%
from Perceptron import Perceptron

# %% [markdown]
# Let's create a random dataset with labels for two classes.

# %%
X, y = datasets.make_blobs(n_samples=100, centers=2, n_features=2)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %% [markdown]
# We only need to fit the model to the data. Our training regime wil run as stated previously on the Perceptron.py file.

# %%
P = Perceptron()
P.fit(X, y)

# %% [markdown]
# Shows error decreasing over epochs.

# %%
plt.figure(figsize=(10, 8))
plt.plot(P.misses)
plt.title("Missclassification")
plt.xlabel("Epochs")
plt.ylabel("Instances")
plt.show()

# %% [markdown]
# Get the weights of the network. This are equivalent in this case to the weights of a linear regressor, including the bias term.

# %%
P.weights
# Out:
# array([[ 0.        ],
#        [-0.01001   ],
#        [-0.00871385]])

# %% [markdown]
# Based on weights, plot the decision boundary.

# %%
def decision_boundary(X, y, theta):
    
    x1 = [min(X[:,0]), max(X[:,0])]
    m = -theta[1]/theta[2]
    c = -theta[0]/theta[2]
    x2 = m*x1 + c
    
    # Plotting
    fig = plt.figure(figsize=(10,8))
    plt.plot(X[:, 0][y==0], X[:, 1][y==0], "r^")
    plt.plot(X[:, 0][y==1], X[:, 1][y==1], "bs")
    plt.xlabel("X1")
    plt.ylabel("X2")
    plt.title("Perceptron Decision Boundary")
    plt.plot(x1, x2, 'y-')

# %%
decision_boundary(X, y, P.weights)
